# %%
# !nvidia-smi

# %%
# !lscpu

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ROOT = "/content/drive/MyDrive/Wild-Species-Classification" 
# %cd $ROOT

# %%
# !python "src/train_resnet50.py" --epochs 10 --batch_size 64 --ckpts "resnet50"

# %%
# !python "src/test_resnet50.py" ---batch_size 64 --ckpts "resnet50"
